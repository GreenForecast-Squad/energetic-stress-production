# %%
import pandas as pd
import numpy as np

# %%
data_2018 = pd.read_excel("data/RTE/eCO2mix_RTE_Annuel-Definitif_2018.xlsx")
data_2018
# Out:
#                                                Périmètre               Nature  \
# 0                                                 France  Données définitives
# 1                                                 France  Données définitives
# 2                                                 France  Données définitives
# 3                                                 France  Données définitives
# 4                                                 France  Données définitives
# ...                                                  ...                  ...
# 35036                                             France  Données définitives
# 35037                                             France  Données définitives
# 35038                                             France  Données définitives
# 35039                                             France  Données définitives
# 35040  RTE ne pourra être tenu responsable de l'usage...                  NaN
#
# ...

# %%
tempo_2018 = pd.read_excel("eCO2mix_RTE_tempo_2018-2019.xls")
tempo_2018
