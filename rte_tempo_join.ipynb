# %%
import pandas as pd
import numpy as np

# %%
data_2018 = pd.read_excel("data/RTE/eCO2mix_RTE_Annuel-Definitif_2018.xlsx")

# %%
tempo_2018 = pd.read_excel("data/RTE/eCO2mix_RTE_tempo_2018-2019.xlsx")
tempo_2018.drop(tempo_2018.tail(1).index,inplace=True) # drop dernière row

# %%
tempo_2018['Date'] =  pd.to_datetime(tempo_2018['Date'], format='%Y-%m-%d %H:%M:%S')

# %%
data = pd.merge(data_2018, tempo_2018, on="Date")
data
# Out:
#       Périmètre               Nature       Date    Heures  Consommation  \
# 0        France  Données définitives 2018-09-01  00:00:00       45889.0
# 1        France  Données définitives 2018-09-01  00:15:00           NaN
# 2        France  Données définitives 2018-09-01  00:30:00       43860.0
# 3        France  Données définitives 2018-09-01  00:45:00           NaN
# 4        France  Données définitives 2018-09-01  01:00:00       40646.0
# ...         ...                  ...        ...       ...           ...
# 11707    France  Données définitives 2018-12-31  22:45:00           NaN
# 11708    France  Données définitives 2018-12-31  23:00:00       63977.0
# 11709    France  Données définitives 2018-12-31  23:15:00           NaN
# 11710    France  Données définitives 2018-12-31  23:30:00       63803.0
# 11711    France  Données définitives 2018-12-31  23:45:00           NaN
#
#        Prévision J-1  Prévision J  Fioul  Charbon     Gaz  ...  Gaz - Cogén.  \
# ...
